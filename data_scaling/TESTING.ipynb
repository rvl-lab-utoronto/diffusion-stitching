# %% [markdown]
# ## decagon testing notebook

# %%
from utilities.decagon_env import *
plt.rcParams["font.family"] = "Times New Roman"

env = Decagon()
fig, ax = env.get_mpl_plot()
fig.set_dpi(400)

# %%
# making smaller data splits
import numpy as np
import matplotlib as mpl
save_directory = 'decagon_data'


training_split = np.load(save_directory + '/train_data.npy',allow_pickle=True)

from utilities.decagon_env import *
env = Decagon()
fig, ax = env.get_mpl_plot()
fig.set_dpi(400)

gradient = np.linspace(0, 1, 512)
cmap = mpl.colormaps['viridis']
plt.scatter(training_split[3]['trajectory'][:,0],training_split[3]['trajectory'][:,1],c=cmap(gradient),zorder=-1)
